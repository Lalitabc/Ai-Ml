# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
import os
os.chdir('C:\\Users\\Lalit Max\\Desktop\\Ai Ml\\Supervised-Learning\\Linear-Regression')
os.getcwd()
# Out:
# 'C:\\Users\\Lalit Max\\Desktop\\Ai Ml\\Supervised-Learning\\Linear-Regression'

# %%
df = pd.read_csv('age_premium.csv')
df
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='age', y= 'premium', data  = df)
plt.show()

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['age']], df[['premium']])
# Out:
# LinearRegression()

# %%
ans = reg.predict([[21]])
# Out:
# C:\Users\Lalit Max\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
ans
# Out:
# array([[13480.]])

# %%
reg.coef_
# Out:
# array([[1780.]])

# %%
reg.intercept_
# Out:
# array([-23900.])
